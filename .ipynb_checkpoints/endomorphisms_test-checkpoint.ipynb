# %%
import sys

sys.path
# Out:
# ['/Users/danil/SageMath/klrw_algebra',
#  '/private/var/tmp/sage-10.0-current/local/var/lib/sage/venv-python3.11.1/lib/python311.zip',
#  '/private/var/tmp/sage-10.0-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11',
#  '/private/var/tmp/sage-10.0-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/lib-dynload',
#  '',
#  '/Users/danil/.sage/local/lib/python3.11/site-packages',
#  '/private/var/tmp/sage-10.0-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages']

# %%
from klrw_endomorphism import KLRWEndomorphismAlgebra
from framed_dynkin import FramedDynkinDiagram_with_dimensions, NodeInFramedQuiver
from klrw_algebra import KLRWAlgebra
#from klrw_state import KLRWstate_set

# %%
DD = FramedDynkinDiagram_with_dimensions(CartanType(["A",1]))
#dim W1 = 1
DD.set_dim(2,1, True)
#dim V1 = 1
DD.set_dim(3,1, False)
#dim W2 = 0 
#DD.set_dim(2,2, True)
#dim V2 = 1
#DD.set_dim(2,2, False)

from framed_dynkin import NodeInFramedQuiver
V1 = NodeInFramedQuiver(1, False)
W1 = NodeInFramedQuiver(1, True)
#V2 = NodeInFramedQuiver(2, False)
#W2 = NodeInFramedQuiver(2, True)

DD
# Out:
# 2
# W1
# □
# |
# ◯
# V1
# 3

# %%
KLRW = KLRWAlgebra(QQ,DD, warnings = True, vertex_prefix = "h")
KLRW.base().inject_variables()
# Out:
# Defining h_1, u_1, x_1_1, x_1_2, x_1_3

# %%
BB = KLRW.KLRWBraid
SS = BB.KLRWstate_set

# %%
A = KLRW.endomorphisms
A.inject_variables()
state = SS._element_constructor_((V1,V1,W1,W1,V1))
state2 = SS._element_constructor_((V1,W1,V1,W1,V1))
#braid = BB._element_constructor_(state)
II = KLRW.idempotent(state)
III = KLRW.idempotent(state2)
#eval("h_1*y1")
for braid,_ in III*l3*y2*l2*r3*y1:
#    print(braid)
    braid.print_ascii_art()
# Out:
# Defining y1, y2, l1, l2, l3, r1, r2, r3
# V1  V1  W1  W1  V1
# |   |   |   |   |
#  \ /    |   |   |
#   X     |   |   |
#  / \    |   |   |
# |   \   |   |   |
# |    \ /    |   |
# |     X     |   |
# |    / \    |   |
# |   |   |   |   |
# V1  W1  V1  W1  V1
#
# V1  V1  W1  W1  V1
# |   |   |   |   |
#  \ /    |   |   |
#   X     |   |   |
#  / \    |   |   |
# |   \   |   |   |
# |    \ /    |   |
# |     X     |   |
# |    / \    |   |
# |   |   \   |   |
# |   |    \ /    |
# |   |     X     |
# |   |    / \    |
# |   |   |   \   |
# |   |   |    \ /
# |   |   |     X
# |   |   |    / \
# |   |   |   /   |
# |   |    \ /    |
# |   |     X     |
# |   |    / \    |
# |   |   |   |   |
# V1  W1  V1  W1  V1

# %%
from sage.monoids.free_monoid import FreeMonoid, FreeMonoidElement
FreeMonoidElement??
# Out:
# Init signature: FreeMonoidElement(F, x, check=True)
# Docstring:
#    Element of a free monoid.
#
#    EXAMPLES:
#
#       sage: a = FreeMonoid(5, 'a').gens()
#       sage: x = a[0]*a[1]*a[4]**3
#       sage: x**3
#       a0*a1*a4^3*a0*a1*a4^3*a0*a1*a4^3
#       sage: x**0
#       1
#       sage: x**(-1)
#       Traceback (most recent call last):
#       ...
#       NotImplementedError
# Source:
# class FreeMonoidElement(MonoidElement):
#     """
#     Element of a free monoid.
#
#     EXAMPLES::
#
#         sage: a = FreeMonoid(5, 'a').gens()
#         sage: x = a[0]*a[1]*a[4]**3
#         sage: x**3
#         a0*a1*a4^3*a0*a1*a4^3*a0*a1*a4^3
#         sage: x**0
#         1
#         sage: x**(-1)
#         Traceback (most recent call last):
#         ...
#         NotImplementedError
#     """
#     def __init__(self, F, x, check=True):
#         """
#         Create the element `x` of the FreeMonoid `F`.
#
#         This should typically be called by a FreeMonoid.
#         """
# ...

# %%
for x,y in y1:
    print(x,y)
y1.leading_monomial().__class__
y1.leading_item()[0].__class__
# Out:
# y1 1
# <class 'sage.monoids.free_monoid.FreeMonoid_with_category.element_class'>

# %%
l = [0,1,4]
SS._element_constructor_(V1 if x in l else W1 for x in range(5))
# Out:
# (V1, V1, W1, W1, V1)
